# %%
import pandas as pd
import warnings
from openpyxl import load_workbook
import pandas as pd
import numpy as np
from matplotlib import font_manager,rc
import matplotlib.pyplot as plt
rc('font',family='AppleGothic')
# 경고 무시
warnings.simplefilter("ignore")

# %%
pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (2.0.1)
# Collecting pandas
#   Downloading pandas-2.0.2-cp310-cp310-macosx_11_0_arm64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 109.2 kB/s eta 0:00:0000:0100:03
# Requirement already satisfied: pytz>=2020.1 in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: tzdata>=2022.1 in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.1
#     Uninstalling pandas-2.0.1:
#       Successfully uninstalled pandas-2.0.1
# Successfully installed pandas-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
consumer = pd.read_excel('consumer_values.xlsx',engine='openpyxl',header=None)
consumer = consumer.iloc[2:4,:]
consumer.columns = consumer.iloc[0]
consumer = consumer.iloc[1:]
consumer = consumer.iloc[:,1:]
consumer.columns = [i.replace('월','') for i in consumer.columns]
A = consumer.iloc[0]
A = pd.to_numeric(A, errors='coerce')
A.astype(float)
A.head()
# Out:
# 202002    97.8
# 202003    80.4
# 202004    73.3
# 202005    79.7
# 202006    83.7
# Name: 3, dtype: float64

# %%
cospi = pd.read_excel('코스피.xlsx',engine='openpyxl')
cospi = cospi.drop(cospi.columns[0], axis=1)
cospi.columns = [i.replace('.','') for i in cospi.columns]
B = cospi.iloc[0]
B.astype(float)
B.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39 entries, 202002 to 202304
# Series name: 0
# Non-Null Count  Dtype
# --------------  -----
# 39 non-null     float64
# dtypes: float64(1)
# memory usage: 624.0+ bytes

# %% [markdown]
# # 코스피와 소비자심리지수와의 corr

# %%
corrAB = A.corr(B)
print(corrAB)
# Out:
# 0.8415980240515305

# %%
# 최소-최대 정규화
normalized_A = (A - A.min()) / (A.max() - A.min())
normalized_B = (B - B.min()) / (B.max() - B.min())

# 데이터 시각화
x = np.arange(len(A))  # x 축을 시간으로 가정
plt.plot(x, normalized_A, label='A')
plt.plot(x, normalized_B, label='B')
plt.title('Correlation Trend')
plt.xlabel('Time')
plt.ylabel('Normalized Values')
plt.legend()
plt.show()

# %% [markdown]
# # 예금금리와 소비자심리지수와의 corr

# %%
depo = pd.read_excel('예금금리.xlsx',engine='openpyxl')
depo.columns = [i.replace('.','') for i in depo.columns]
depo = depo.set_index(depo.columns[0])

A = A.drop(A.index[-1])
for i in range(10):
    print(depo.index[i],end=' ')
    C = depo.iloc[i]
    print(A.corr(C))
# Out:
# 　　　　　　　　　대기업대출 -0.3185045203474792
# 　　　　　　　　　중소기업대출 -0.33227674903295895
# 　　　　　　　　　운전자금대출 -0.31854014700506894
# 　　　　　　　　　시설자금대출 -0.330973977577628
# 　　　　　　　　　소액대출 (500만원 이하) -0.2829081205755835
# 　　　　　　　　　주택담보대출 -0.37373613130318495
# 　　　　　　　　　예・적금담보대출 -0.46013601701974777
# 　　　　　　　　　보증대출 -0.3842891987143586
# 　　　　　　　　　일반신용대출 3) -0.27838851824303523
# 　　　　　　　　　집단대출 3) -0.21878884170555996

# %% [markdown]
# # 환율과 소비자심리지수와의 corr

# %%
exchange = pd.read_csv('환율.csv')
exchange = exchange.set_index('날짜')['종가']
D = pd.Series(exchange)
D.index = pd.to_datetime(D.index).strftime('%Y%m')
D = D.str.replace(',','').astype(float)
print(A.corr(D))
# Out:
# -0.3470924667978699

# %% [markdown]
# # 비트코인(종가)와 소비자심리지수와의 corr

# %%
bitcoin = pd.read_csv('bitcoin.csv')
bitcoin1 = bitcoin.set_index('날짜')['종가']
bitcoin1 = pd.Series(bitcoin1)
formatted_index = [pd.to_datetime(idx, format='%Y년 %m월').strftime('%Y%m') for idx in bitcoin1.index]
bitcoin1.index = formatted_index
bitcoin1 = bitcoin1.str.replace(',','').astype(float)
E = bitcoin1[::-1]
E = E.drop(E.index[-1])
print(A.corr(E))
# Out:
# 0.8090559986303727

# %% [markdown]
# # 비트코인(매수량)와 소비자심리지수와의 corr

# %%
def convert_value(value):
    if "B" in value:
        return float(value.replace("B", "")) * 1000
    elif "M" in value:
        return float(value.replace("M", ""))
    else:
        return float(value)

bitcoin = pd.read_csv('bitcoin.csv')
bitcoin2 = bitcoin.set_index('날짜')['거래량']
bitcoin2 = pd.Series(bitcoin2)
formatted_index = [pd.to_datetime(idx, format='%Y년 %m월').strftime('%Y%m') for idx in bitcoin2.index]
bitcoin2.index = formatted_index
bitcoin2 = bitcoin2.apply(convert_value)
F = bitcoin2[::-1]
F = F.drop(F.index[-1])
print(A.corr(F))
# Out:
# 0.205583350087156

# %% [markdown]
# # 유가와 소비자심리지수와의 corr

# %%
oil = pd.read_excel('유가.xlsx')
oil
# Out:
#   기준원유                    항목  2020.02  2020.03  2020.04  2020.05  2020.06  \
# 0   원유  국제유가(Dubai) (US$/배럴)     54.2     33.7     20.4     30.5     40.8
#
#    2020.07  2020.08  2020.09  ...  2022.06  2022.07  2022.08  2022.09  \
# 0     43.3       44     41.5  ...    113.3    103.1     96.6       91
#
#    2022.10  2022.11  2022.12  2023.01  2023.02  2023.03
# 0     91.2     86.3     77.2     80.4     82.1     78.5
#
# [1 rows x 40 columns]

# %%
oil = pd.read_excel('유가.xlsx')
oil = oil.drop(oil.columns[0], axis=1)
oil = oil.drop(oil.columns[0], axis=1)
oil
oil.columns = [i.replace('.','') for i in oil.columns]
G = oil.iloc[0]
G.astype(float)
print(A.corr(G))
# Out:
# 0.4825697721071269

# %% [markdown]
# # 물가지수와 소비자심리지수와의 corr

# %%
price = pd.read_excel('물가지수.xlsx')
price = price.drop(price.columns[0], axis=1)
price.columns = [i.replace('.','') for i in price.columns]
price = price.set_index(price.columns[0])

for i in range(13):
    print(price.index[i],end=' ')
    H = price.iloc[i]
    H.astype(float)
    print(A.corr(H))
# Out:
# 0 총지수 0.06787854751979494
# 01 식료품 및 비주류음료 0.17727502619206423
# 02 주류 및 담배 -0.025720259838948527
# 03 의류 및 신발 -0.13008215834449122
# 04 주택, 수도, 전기 및 연료 -0.0595231658239171
# 05 가정용품 및 가사 서비스 0.014543716554947534
# 06 보건 -0.25656698699033725
# 07 교통 0.2779419790067045
# 08 통신 -0.3073537411312293
# 09 오락 및 문화 -0.12300106187479137
# 10 교육 0.08001989310554929
# 11 음식 및 숙박 -0.0009512284515362276
# 12 기타 상품 및 서비스 -0.03916461650118235

# %% [markdown]
# # 월간 카드 실적과 소비자심리지수와의 corr

# %%
card = pd.read_excel('월간_국내카드승인실적.xlsx')
card.columns = [i.replace('.','') for i in card.columns]
card = card.set_index(card.columns[0])

for j in range(8):
    print(card.index[j],end=' ')
    I = card.iloc[j]
    I.astype(float)
    print(A.corr(I))
# Out:
# 도매 및 소매업 0.18003252650660548
# 운수업 -0.02828475131576171
# 숙박 및 음식점업 -0.14393846606093758
# 사업시설관리 및 사업지원 서비스업 -0.06876553166980588
# 교육서비스업 0.2975350902455476
# 보건업 및 사회복지 서비스업 0.2768288674317257
# 예술, 스포츠 및 여가관련 서비스업 0.08167938454256161
# 협회 및 단체, 수리 및 기타 개인 서비스업 0.07426408104802024

# %% [markdown]
# ## 교육서비스업이 가장 높음

# %% [markdown]
# # 전월세 지수와 소비자심리지수와의 corr

# %%
house = pd.read_excel('전월세통합지수.xlsx')
house.columns = [i.replace('.','') for i in house.columns]
house = house.set_index(house.columns[0])
house = house.drop(house.columns[0], axis=1)

for i in range(4):
    print(house.index[i],end=' ')
    J = house.iloc[i]
    J.astype(float)
    print(A.corr(J))
# Out:
# 종합 0.5976645506094004
# 아파트 0.6186620317577032
# 연립다세대 0.410378166074052
# 단독주택 0.19288941195895168

# %% [markdown]
# # 공사완료후 미분양현황과의 corr

# %%
unsold = pd.read_excel('공사완료후_미분양현황.xlsx')
unsold.columns = [i.replace('.','') for i in unsold.columns]
unsold = unsold.drop(unsold.columns[0], axis=1)
unsold = unsold.drop(unsold.columns[0], axis=1)
unsold = unsold.drop([0,1])
unsold = unsold.astype(float)
unsold = unsold.iloc[0]
print(A.corr(unsold))
# Out:
# -0.5673349635623967

# %% [markdown]
# ## 사교육(교육비)는  월별 데이터 없음

# %% [markdown]
# # 상관관계 높은 항목들은 1,3,5개월 단위로 묶어보고 언제 가장 예측이 잘 될 지

# %% [markdown]
# ## 코스피 회귀분석

# %%
consumer = pd.read_excel('consumer_values.xlsx',engine='openpyxl',header=None)
consumer = consumer.iloc[2:4,:]
consumer.columns = consumer.iloc[0]
consumer = consumer.iloc[1:]
consumer = consumer.iloc[:,1:]
consumer.columns = [i.replace('월','') for i in consumer.columns]
A = consumer.iloc[0]
A = pd.to_numeric(A, errors='coerce')
A.astype(float)

cospi = pd.read_excel('코스피.xlsx',engine='openpyxl')
cospi = cospi.drop(cospi.columns[0], axis=1)
cospi.columns = [i.replace('.','') for i in cospi.columns]
B = cospi.iloc[0]
B.astype(float)
# Out:
# 202002    2167.12
# 202003    1786.75
# 202004    1849.59
# 202005    1965.17
# 202006    2134.70
# 202007    2195.95
# 202008    2349.87
# 202009    2371.52
# 202010    2357.82
# 202011    2504.18
# 202012    2755.77
# 202101    3089.27
# 202102    3092.41
# 202103    3032.47
# 202104    3165.08
# 202105    3169.20
# 202106    3259.14
# 202107    3254.57
# 202108    3182.50
# 202109    3141.70
# 202110    2989.87
# 202111    2964.30
# 202112    2988.49
# 202201    2865.55
# 202202    2724.02
# 202203    2698.72
# 202204    2703.24
# 202205    2628.34
# 202206    2474.95
# 202207    2362.79
# 202208    2479.57
# 202209    2333.93
# 202210    2230.27
# 202211    2417.56
# 202212    2361.28
# 202301    2362.36
# 202302    2450.34
# 202303    2417.56
# 202304    2523.29
# Name: 0, dtype: float64

# %%
print(A.corr(B))
# Out:
# 0.8415980240515305

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.0-cp310-cp310-macosx_11_0_arm64.whl (9.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 2.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging>=21.3 in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (from statsmodels) (22.0)
# Requirement already satisfied: numpy>=1.18 in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (from statsmodels) (1.10.0)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pandas>=1.0 in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (from statsmodels) (2.0.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (from pandas>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (from pandas>=1.0->statsmodels) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: six in /Users/whisoo/opt/anaconda3/envs/2023-DS-B/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.3 statsmodels-0.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm

# %%
# 시리즈 데이터를 데이터프레임으로 변환
df = pd.DataFrame({'A': pd.Series(A), 'B': pd.Series(B)})

# 상수항 추가
df['Intercept'] = 1

# 회귀분석 모델 생성
model = sm.OLS(df['A'], df[['B', 'Intercept']])

# 회귀분석 수행
result = model.fit()

# 회귀분석 결과 출력
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      A   R-squared:                       0.708
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     89.84
# Date:                Tue, 30 May 2023   Prob (F-statistic):           1.94e-11
# Time:                        16:19:21   Log-Likelihood:                -116.48
# No. Observations:                  39   AIC:                             237.0
# Df Residuals:                      37   BIC:                             240.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# B              0.0187      0.002      9.478      0.000       0.015       0.023
# Intercept     46.3975      5.201      8.921      0.000      35.859      56.936
# ==============================================================================
# Omnibus:                        0.553   Durbin-Watson:                   1.022
# Prob(Omnibus):                  0.758   Jarque-Bera (JB):                0.653
# Skew:                           0.099   Prob(JB):                        0.721
# Kurtosis:                       2.398   Cond. No.                     1.74e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.74e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### R-squared (R제곱): R제곱은 모델이 종속 변수의 변동을 얼마나 설명할 수 있는지를 나타내는 지표.
# ### R제곱 값은 0과 1 사이의 값을 가지며, 값이 1에 가까울수록 모델이 데이터를 잘 설명한다는 의미.
# ### 0.708

# %% [markdown]
# ### p-value 값이 0.05보다 작음 -> 통계적 유의미성

# %%
import matplotlib.dates as mdates

dates = pd.to_datetime(A.index, format='%Y%m')
# 최소-최대 정규화
normalized_A = (A - A.min()) / (A.max() - A.min())
normalized_B = (B - B.min()) / (B.max() - B.min())

# 데이터 시각화
plt.figure(figsize=(16,8))
plt.plot(dates, normalized_A, label='심리지수')
plt.plot(dates, normalized_B, label='코스피')

plt.title('Correlation Trend')
plt.xlabel('Time')
plt.ylabel('Normalized Values')
plt.legend()
# x 축 레이블 설정
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# 그래프 출력
plt.gcf().autofmt_xdate()
plt.show()

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# %% [markdown]
# ### Granger 인과성 테스트: 코스피 지수와 소비자심리지수 사이의 인과 관계를 조사할 수 있습니다. Granger 인과성 테스트를 사용하여 한 시계열이 다른 시계열을 예측하는 데 유의한 영향을 미치는지 확인할 수 있습니다.

# %%
# Granger 인과성 분석 수행
result = grangercausalitytests(pd.concat([A, B], axis=1), maxlag=2, verbose=False)

# 결과 출력
for lag in result.keys():
    print(f"Lag Order: {lag}")
    print(f"Granger Causality p-value: {result[lag][0]['ssr_ftest'][1]}")
    print("---------------------------")
# Out:
# Lag Order: 1
# Granger Causality p-value: 1.1899448559012171e-05
# ---------------------------
# Lag Order: 2
# Granger Causality p-value: 0.000928685123383307
# ---------------------------

# %% [markdown]
# ## Lag Order1 ->귀무가설 기각
# ## Lag Order2 -> A가 B를 예측하는 데 기여
# # 코스피 지수의 과거 값이 소비자 심리지수의 현재 값을 예측하는 데 유의미한 정보를 제공한다는 것을 의미

# %% [markdown]
# ### 소비자심리지수는 설문조사이기때문에 산출하는데 소요되는 시간적, 비용적 cost가 존재함
# ## => 과거 코스피지수와 다음달 심리지수의 상관관계 살펴보기

# %%
consumer = pd.read_excel('consumer_values.xlsx',engine='openpyxl',header=None)
consumer = consumer.iloc[2:4,:]
consumer.columns = consumer.iloc[0]
consumer = consumer.iloc[1:]
consumer = consumer.iloc[:,1:]
consumer.columns = [i.replace('월','') for i in consumer.columns]
A = consumer.iloc[0]
A = pd.to_numeric(A, errors='coerce')
A.astype(float)
A_pd = pd.DataFrame({'A':A})
shifted = A_pd.shift(1, axis=0)
shifted = shifted.drop(A.index[0])
shifted = shifted.drop(A.index[-1])
shifted = shifted.squeeze()
shifted_B = B.drop(B.index[0])
shifted_B = shifted_B.drop(shifted_B.index[-1])

print(shifted.corr(shifted_B))
# Out:
# 0.7362799125545639

# %%
# 더 낮음

# %%
consumer = pd.read_excel('consumer_values.xlsx',engine='openpyxl',header=None)
consumer = consumer.iloc[2:4,:]
consumer.columns = consumer.iloc[0]
consumer = consumer.iloc[1:]
consumer = consumer.iloc[:,1:]
consumer.columns = [i.replace('월','') for i in consumer.columns]
A = consumer.iloc[0]
A = pd.to_numeric(A, errors='coerce')
A.astype(float)
A_pd = pd.DataFrame({'A':A})
shifted = A_pd.shift(2, axis=0)
shifted = shifted.drop(shifted.index[0])
shifted = shifted.drop(shifted.index[0])
shifted = shifted.squeeze()
shifted_B = B.drop(B.index[0])
shifted_B = shifted_B.drop(shifted_B.index[0])

print(shifted.corr(shifted_B))
# Out:
# 0.6592751126699898

# %%
# 두 달 전은 더 낮음

# %%
print(B.corr(E))
# Out:
# 0.8625625634050671

# %%
소비자물가지수에 따라서 가장 영향을 많이 받는 품목을 구해서, 코스피지수를 통한 판매전략.
